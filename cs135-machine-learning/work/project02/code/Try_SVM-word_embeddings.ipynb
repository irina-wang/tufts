# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer

# %%
import os
import numpy as np

import warnings

import sklearn.linear_model
import sklearn.metrics

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn') # pretty matplotlib plots

x_train_df = pd.read_csv('../data/data_reviews/x_train.csv')
y_train_df = pd.read_csv('../data/data_reviews/y_train.csv')
x_test_df = pd.read_csv('../data/data_reviews/x_test.csv')

# %%
x_train = x_train_df['text'] 
x_test = x_test_df['text']
x_train
# Out:
# 0       Oh and I forgot to also mention the weird colo...
# 1                            THAT one didn't work either.
# 2                                      Waste of 13 bucks.
# 3       Product is useless, since it does not have eno...
# 4       None of the three sizes they sent with the hea...
#                               ...
# 2395    The sweet potato fries were very good and seas...
# 2396    I could eat their bruschetta all day it is dev...
# 2397                                 Ambience is perfect.
# 2398    We ordered the duck rare and it was pink and t...
# 2399         Service was good and the company was better!
# Name: text, Length: 2400, dtype: object

# %%
amazon_i = np.where(x_train_df['website_name']=='amazon')
imdb_i = np.where(x_train_df['website_name']=='imdb')
yelp_i =  np.where(x_train_df['website_name']=='yelp')

# %%
import pandas as pd
import numpy as np
import sklearn.neighbors

from collections import OrderedDict

word_embeddings = pd.read_csv('../data/pretrained_word_embeddings/glove.6B.50d.txt.zip',
                               header=None, sep=' ', index_col=0,
                               nrows=100000, compression='zip', encoding='utf-8', quoting=3)
# Build a dict that will map from string word to 50-dim vector
word_list = word_embeddings.index.values.tolist()
word2vec = OrderedDict(zip(word_list, word_embeddings.values))

## Show some examples

n_words = len(word2vec.keys())
print("word2vec['happy'] = ")
print(word2vec['happy'])

## Try some analogies
def analogy_lookup(a1, a2, b1):
    target_vec = word2vec[a2] - word2vec[a1] + word2vec[b1]
    knn = sklearn.neighbors.NearestNeighbors(n_neighbors=7, metric='euclidean', algorithm='brute')
    knn.fit(word_embeddings.values)
    dists, indices = knn.kneighbors(target_vec[np.newaxis,:])
    print("Query: %s:%s -> %s:____" % (a1, a2, b1))
    for ii, vv in enumerate(indices[0]):
        print("   %20s  at dist %.3f" % (word_list[vv], dists[0,ii]))

analogy_lookup('movie', 'film', 'theater')
# Out:
# word2vec['happy'] =
# [ 0.092086  0.2571   -0.58693  -0.37029   1.0828   -0.55466  -0.78142
#   0.58696  -0.58714   0.46318  -0.11267   0.2606   -0.26928  -0.072466
#   1.247     0.30571   0.56731   0.30509  -0.050312 -0.64443  -0.54513
#   0.86429   0.20914   0.56334   1.1228   -1.0516   -0.78105   0.29656
#   0.7261   -0.61392   2.4225    1.0142   -0.17753   0.4147   -0.12966
#  -0.47064   0.3807    0.16309  -0.323    -0.77899  -0.42473  -0.30826
#  -0.42242   0.055069  0.38267   0.037415 -0.4302   -0.39442   0.10511
#   0.87286 ]
# Query: movie:film -> theater:____
#                 theatre  at dist 1.977
#                 theater  at dist 2.158
#                  cinema  at dist 3.639
#                   opera  at dist 3.654
#                  ballet  at dist 3.729
#                ensemble  at dist 3.817
#                  studio  at dist 3.967

# %% [markdown]
# ## Preprocess

# %%
pip install autocorrect
# Out:
# Requirement already satisfied: autocorrect in /Users/mac/opt/anaconda3/envs/ml135_env/lib/python3.8/site-packages (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/mac/.local/lib/python3.8/site-packages (3.6.2)
# Requirement already satisfied: joblib in /Users/mac/opt/anaconda3/envs/ml135_env/lib/python3.8/site-packages (from nltk) (1.0.0)
# Requirement already satisfied: click in /Users/mac/opt/anaconda3/envs/ml135_env/lib/python3.8/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in /Users/mac/opt/anaconda3/envs/ml135_env/lib/python3.8/site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: tqdm in /Users/mac/opt/anaconda3/envs/ml135_env/lib/python3.8/site-packages (from nltk) (4.60.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from autocorrect import Speller
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
porterstemmer = PorterStemmer()
wnl = WordNetLemmatizer()
spell = Speller()

common_words = pd.read_csv('../data/data_reviews/modified_stopword.txt')

# %%
stop_words = common_words['words']
test_stop_words = pd.Series(stop_words).array

# %%
import re

def simple_tokenizer(str_input):
    words = re.sub(r"[^A-Za-z]", " ", str_input).lower().split()   
    return words

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

def stemming_tokenizer(str_input):
    words = decontracted(str_input)
    words = re.sub(r"[^A-Za-z]", " ", str_input).lower().split()
    
    # autocorrect
    test_names = words
    test_names_len = len(words)
    words = [spell(test_names[i]) for i in range(test_names_len)]

    # prune words
#     def prune_food(w):
#         if w == 'bones' or w == 'bone' or w == 'fish' or w == 'worms' or w == 'worm':
#             w = 'food'
#         return w
    
#     words = [prune_food(word) for word in words]
    
    # stemming 
#     porter_stemmer = PorterStemmer()
#     words = [porter_stemmer.stem(word) for word in words]
    
    #remove non important words
#     non_important = ['film', 'movie','apple', 'juice']
#     words = [w for w in words if w not in non_important]
    
    stop_words = common_words['words']
    stop_words = pd.Series(stop_words).array
    words = [w for w in words if w not in stop_words]
    
    return words

# %%
words = [stemming_tokenizer(x_train[i]) for i in range(len(x_train))]

flat_list = sum(words, [])
len(flat_list)

flat_list
# Out:
# ['oh',
#  'forgot',
#  'to',
#  'also',
#  'mention',
#  'weird',
#  'color',
#  'effect',
#  'on',
#  'phone',
#  'one',
#  'didn',
#  't',
#  'work',
#  'either',
#  'waste',
#  'of',
#  'bucks',
#  'product',
#  'useless',
#  'since',
#  'not',
#  'enough',
#  'charging',
#  'current',
#  'to',
#  'charge',
#  'cellphone',
#  'planning',
#  'to',
#  'use',
#  'with',
#  'none',
#  'of',
#  'three',
#  'sizes',
#  'sent',
#  'with',
#  'headset',
#  'would',
#  'stay',
#  'in',
#  'ears',
#  'worst',
#  'customer',
#  'service',
#  'engage',
#  'still',
#  'lacking',
#  'in',
#  'earbuds',
#  'always',
#  'cuts',
#  'out',
#  'makes',
#  'sound',
#  'then',
#  'says',
#  'signal',
#  'failed',
#  'only',
#  'very',
#  'disappointing',
#  'thing',
#  'there',
#  'no',
#  'speakerphone',
#  'very',
#  'disappointed',
#  'in',
#  'accessoryone',
#  'basically',
#  'service',
#  'very',
#  'bad',
#  'bad',
#  'choice',
#  'only',
#  'thing',
#  'disappoint',
#  'infra',
#  'red',
#  'port',
#  'rida',
#  'horrible',
#  'to',
#  'switch',
#  'times',
#  'feels',
#  'poorly',
#  'constructed',
#  'menus',
#  'difficult',
#  'to',
#  'navigate',
#  'buttons',
#  'so',
#  'recessed',
#  'difficult',
#  'to',
#  'push',
#  'don',
#  't',
#  'make',
#  'same',
#  'mistake',
#  'muddy',
#  'low',
#  'quality',
#  'sound',
#  'casing',
#  'around',
#  'wire',
#  's',
#  'insert',
#  'poorly',
#  'super',
#  'glued',
#  'slid',
#  'off',
#  'advise',
#  'everyone',
#  'not',
#  'fooled',
#  'doesn',
#  't',
#  'hold',
#  'charge',
#  'waste',
#  'of',
#  'time',
#  'm',
#  'very',
#  'disappointed',
#  'with',
#  'decision',
#  'also',
#  'didn',
#  't',
#  'like',
#  'on',
#  'button',
#  'felt',
#  'like',
#  'would',
#  'crack',
#  'with',
#  'use',
#  'bought',
#  'hoping',
#  'could',
#  'make',
#  'bluetooth',
#  'headset',
#  'fit',
#  'better',
#  'but',
#  'things',
#  'made',
#  'impossible',
#  'to',
#  'wear',
#  'tried',
#  'units',
#  'both',
#  'failed',
#  'within',
#  'months',
#  'pros',
#  'also',
#  'difficult',
#  'to',
#  'put',
#  'on',
#  'd',
#  'recommend',
#  'avoiding',
#  'product',
#  'down',
#  'drain',
#  'absolute',
#  'junk',
#  'can',
#  't',
#  'store',
#  'anything',
#  'but',
#  'phone',
#  'numbers',
#  'to',
#  'sim',
#  'very',
#  'disappointing',
#  'would',
#  'not',
#  'recommend',
#  'item',
#  'to',
#  'anyone',
#  'big',
#  'disappointment',
#  'with',
#  'calendar',
#  'sync',
#  'not',
#  'impressed',
#  'just',
#  'not',
#  'work',
#  'even',
#  'fully',
#  'charged',
#  'before',
#  'went',
#  'to',
#  'bed',
#  'turned',
#  'off',
#  'blue',
#  'tooth',
#  'wi',
#  'fi',
#  'noticed',
#  'only',
#  'left',
#  'in',
#  'morning',
#  'plus',
#  'seriously',
#  'not',
#  'believe',
#  'worth',
#  'steep',
#  'price',
#  'point',
#  'in',
#  'house',
#  'getting',
#  'dropped',
#  'coverage',
#  'upstairs',
#  'no',
#  'coverage',
#  'in',
#  'basement',
#  'phone',
#  'takes',
#  'forever',
#  'to',
#  'charge',
#  'like',
#  'to',
#  'hours',
#  'literally',
#  'very',
#  'unreliable',
#  'service',
#  'from',
#  't',
#  'mobile',
#  'down',
#  'drain',
#  'because',
#  'of',
#  'weak',
#  'snap',
#  'simple',
#  'little',
#  'phone',
#  'to',
#  'use',
#  'but',
#  'wreckage',
#  'unacceptable',
#  'pretty',
#  'piece',
#  'of',
#  'junk',
#  'so',
#  'embarrassing',
#  'also',
#  'ears',
#  'hurt',
#  'try',
#  'to',
#  'push',
#  'ear',
#  'plug',
#  'into',
#  'ear',
#  'unfortunately',
#  'ability',
#  'to',
#  'actually',
#  'know',
#  'receiving',
#  'call',
#  'rather',
#  'important',
#  'feature',
#  'phone',
#  'pitiful',
#  'in',
#  'respect',
#  'first',
#  'phone',
#  've',
#  'so',
#  'cheaply',
#  'made',
#  'awkward',
#  'to',
#  'use',
#  'unreliable',
#  'horrible',
#  'phone',
#  'looking',
#  'for',
#  'good',
#  'quality',
#  'motorola',
#  'headset',
#  'keep',
#  'looking',
#  'isn',
#  't',
#  'father',
#  'v',
#  'battery',
#  'dying',
#  'after',
#  'year',
#  'battery',
#  'went',
#  'completely',
#  'dead',
#  'on',
#  'headset',
#  'defective',
#  'crap',
#  'poor',
#  'construction',
#  'work',
#  'about',
#  'weeks',
#  'then',
#  'break',
#  'could',
#  'not',
#  'get',
#  'strong',
#  'enough',
#  'signal',
#  'really',
#  'wanted',
#  'plantronics',
#  'to',
#  'right',
#  'one',
#  'but',
#  'too',
#  'many',
#  'issues',
#  'for',
#  'good',
#  'excellent',
#  'starter',
#  'wireless',
#  'headset',
#  'performed',
#  'awful',
#  'baffled',
#  'tiny',
#  'incoming',
#  'sound',
#  'severe',
#  'echo',
#  'for',
#  'on',
#  'other',
#  'end',
#  'of',
#  'call',
#  'bt',
#  'battery',
#  'junk',
#  'design',
#  'might',
#  'economic',
#  'in',
#  'theory',
#  'but',
#  'could',
#  'not',
#  'stand',
#  'in',
#  'ear',
#  'camera',
#  'color',
#  'balance',
#  'awful',
#  'dit',
#  'not',
#  'work',
#  'most',
#  'of',
#  'time',
#  'with',
#  'nokia',
#  'looks',
#  'good',
#  'in',
#  'picture',
#  'but',
#  'case',
#  'huge',
#  'disappointment',
#  've',
#  'bluetoooth',
#  'headset',
#  'for',
#  'some',
#  'time',
#  'now',
#  'still',
#  'not',
#  'comfortable',
#  'with',
#  'way',
#  'fits',
#  'on',
#  'ear',
#  'plug',
#  'wrong',
#  'size',
#  'phone',
#  'unusable',
#  'not',
#  'new',
#  'take',
#  'picture',
#  'battery',
#  'drops',
#  'bar',
#  'starts',
#  'keeping',
#  'letting',
#  'know',
#  'diving',
#  's',
#  'so',
#  'stupid',
#  'to',
#  'to',
#  'keep',
#  'buying',
#  'new',
#  'chargers',
#  'car',
#  'chargers',
#  'cradle',
#  'headphones',
#  'car',
#  'kits',
#  'every',
#  'time',
#  'new',
#  'phone',
#  'comes',
#  'out',
#  'poor',
#  'quality',
#  'service',
#  'poor',
#  'product',
#  'm',
#  'bit',
#  'disappointed',
#  'tried',
#  'talking',
#  'real',
#  'loud',
#  'but',
#  'shouting',
#  'on',
#  'telephone',
#  'gets',
#  'old',
#  'still',
#  'told',
#  'wasn',
#  't',
#  'great',
#  'there',
#  's',
#  'horrible',
#  'tick',
#  'sound',
#  'in',
#  'background',
#  'on',
#  'all',
#  'calls',
#  'never',
#  'experienced',
#  'before',
#  'design',
#  'very',
#  'odd',
#  'as',
#  'ear',
#  'clip',
#  'not',
#  'very',
#  'comfortable',
#  'at',
#  'all',
#  'at',
#  'first',
#  'thought',
#  'getting',
#  'good',
#  'deal',
#  'at',
#  'until',
#  'plugged',
#  'into',
#  'phone',
#  'v',
#  'c',
#  'rarr',
#  'dont',
#  'buy',
#  'so',
#  'there',
#  'no',
#  'way',
#  'for',
#  'to',
#  'plug',
#  'in',
#  'here',
#  'in',
#  'us',
#  'unless',
#  'go',
#  'by',
#  'converter',
#  'solo',
#  'technology',
#  'sucks',
#  'doesn',
#  't',
#  'last',
#  'long',
#  'still',
#  'waiting',
#  'm',
#  'sure',
#  'item',
#  'would',
#  'work',
#  'well',
#  'ever',
#  'receive',
#  'poorly',
#  'construct',
#  'hinge',
#  'think',
#  'over',
#  'when',
#  'plan',
#  'to',
#  'own',
#  'one',
#  'sure',
#  'last',
#  'moto',
#  'phone',
#  'for',
#  'problem',
#  'ear',
#  'loops',
#  'made',
#  'of',
#  'weak',
#  'material',
#  'break',
#  'easily',
#  'bottom',
#  'line',
#  'another',
#  'worthless',
#  'cheap',
#  'gimmick',
#  'from',
#  'sprint',
#  'pair',
#  'of',
#  'headphones',
#  'worst',
#  'ever',
#  'sound',
#  'wise',
#  'att',
#  'not',
#  'clear',
#  'sound',
#  'very',
#  'distorted',
#  'to',
#  'yell',
#  'when',
#  'talk',
#  'would',
#  'advise',
#  'to',
#  'not',
#  'purchase',
#  'item',
#  'never',
#  'worked',
#  'very',
#  'well',
#  'doesn',
#  't',
#  'make',
#  'look',
#  'cool',
#  'bought',
#  'mainly',
#  'for',
#  'charger',
#  'broke',
#  'soon',
#  'after',
#  'purchasing',
#  'put',
#  'latest',
#  'os',
#  'on',
#  'v',
#  'g',
#  'now',
#  'likes',
#  'to',
#  'slow',
#  'to',
#  'crawl',
#  'lock',
#  'up',
#  'every',
#  'once',
#  'in',
#  'while',
#  'there',
#  's',
#  'really',
#  'nothing',
#  'bad',
#  'can',
#  'say',
#  'about',
#  'headset',
#  'sending',
#  'back',
#  'came',
#  'over',
#  'from',
#  'verizon',
#  'because',
#  'singular',
#  'nicer',
#  'cell',
#  'phones',
#  'first',
#  'thing',
#  'noticed',
#  'really',
#  'bad',
#  'service',
#  'unreliable',
#  'm',
#  'giving',
#  'up',
#  'after',
#  'phone',
#  'got',
#  'to',
#  'about',
#  'year',
#  'old',
#  's',
#  'slowly',
#  'breaking',
#  'despite',
#  'much',
#  'care',
#  'on',
#  'part',
#  'waste',
#  'of',
#  'money',
#  'don',
#  't',
#  'waste',
#  'money',
#  'time',
#  'due',
#  'to',
#  'happening',
#  'on',
#  'every',
#  'call',
#  'forced',
#  'to',
#  'stop',
#  'using',
#  'headset',
#  'checked',
#  'everywhere',
#  'there',
#  'no',
#  'feature',
#  'for',
#  'really',
#  'disappointing',
#  'not',
#  'fit',
#  'll',
#  'looking',
#  'for',
#  'new',
#  'apiece',
#  'however',
#  'keypads',
#  'so',
#  'tiny',
#  'sometimes',
#  'reach',
#  'wrong',
#  'buttons',
#  'unfortunately',
#  'not',
#  'work',
#  'couldn',
#  't',
#  'figure',
#  'out',
#  'worst',
#  'software',
#  'ever',
#  'used',
#  'could',
#  'give',
#  'zero',
#  'stars',
#  'would',
#  'lousy',
#  'product',
#  'lasted',
#  'one',
#  'day',
#  'then',
#  'blew',
#  'up',
#  'bought',
#  'for',
#  'mother',
#  'problem',
#  'with',
#  'battery',
#  'not',
#  'impressed',
#  'by',
#  'product',
#  'not',
#  'enough',
#  'volume',
#  'buyer',
#  'very',
#  'careful',
#  'jerk',
#  'on',
#  'phone',
#  'but',
#  'when',
#  'check',
#  'voice',
#  'mail',
#  'at',
#  'night',
#  'keypad',
#  'backlight',
#  'turns',
#  'off',
#  'few',
#  'seconds',
#  'into',
#  'first',
#  'message',
#  'then',
#  'm',
#  'lost',
#  'disappointing',
#  'results',
#  'got',
#  'car',
#  'charger',
#  'not',
#  'even',
#  'after',
#  'week',
#  'charger',
#  'broken',
#  'went',
#  'to',
#  'plug',
#  'in',
#  'started',
#  'smoking',
#  'find',
#  'inexcusable',
#  'so',
#  'will',
#  'probably',
#  'returning',
#  'phone',
#  'perhaps',
#  'changing',
#  'carriers',
#  'get',
#  'pay',
#  'for',
#  'guess',
#  'bad',
#  'quality',
#  's',
#  'not',
#  'says',
#  's',
#  'kind',
#  'of',
#  'embarrassing',
#  'to',
#  'use',
#  'because',
#  'of',
#  'how',
#  'looks',
#  'mostly',
#  's',
#  'embarrassing',
#  'how',
#  'child',
#  'like',
#  'company',
#  'all',
#  'in',
#  'all',
#  'd',
#  'expected',
#  'better',
#  'consumer',
#  'experience',
#  'from',
#  'motorola',
#  'sending',
#  'back',
#  'everything',
#  'about',
#  'product',
#  'wrong',
#  'first',
#  'cheap',
#  'feel',
#  'look',
#  'just',
#  'as',
#  'cheap',
#  'after',
#  'receiving',
#  'using',
#  'product',
#  'for',
#  'just',
#  'days',
#  'broke',
#  'phone',
#  'falls',
#  'out',
#  'easily',
#  'first',
#  'thing',
#  'happened',
#  'tracking',
#  'off',
#  'links',
#  'should',
#  'some',
#  'way',
#  'to',
#  'exchange',
#  'bad',
#  'phone',
#  'for',
#  'return',
#  'unit',
#  'something',
#  'must',
#  'study',
#  'for',
#  'anyone',
#  'interested',
#  'in',
#  'worst',
#  'sins',
#  'of',
#  'industrial',
#  'design',
#  'bt',
#  'headset',
#  'such',
#  'disappointment',
#  'phone',
#  'for',
#  'over',
#  'year',
#  'now',
#  'will',
#  'tell',
#  'not',
#  'great',
#  'piece',
#  'of',
#  'junk',
#  'lose',
#  'more',
#  'calls',
#  'on',
#  'phone',
#  'doesn',
#  't',
#  'work',
#  'at',
#  'all',
#  'bought',
#  'for',
#  'l',
#  'c',
#  'not',
#  'working',
#  'very',
#  'disappointed',
#  'earned',
#  'piece',
#  'breaks',
#  'easily',
#  'can',
#  'barely',
#  'ever',
#  'hear',
#  'on',
#  'constantly',
#  'saying',
#  'doesn',
#  't',
#  'work',
#  'in',
#  'europe',
#  'asia',
#  'ordered',
#  'product',
#  'first',
#  'unhappy',
#  'with',
#  'immediately',
#  'm',
#  'really',
#  'disappointed',
#  'all',
#  'now',
#  'charger',
#  'doesn',
#  't',
#  'work',
#  'horrible',
#  'horrible',
#  'protector',
#  'rip',
#  'off',
#  'over',
#  'charge',
#  'shipping',
#  'case',
#  'more',
#  'less',
#  'extra',
#  'originally',
#  'put',
#  ...]

# %%
len(flat_list)
# Out:
# 20160

# %%
words_te = [stemming_tokenizer(x_test[i]) for i in range(len(x_test))]

flat_list_te = sum(words_te, [])
len(flat_list_te)
# Out:
# 5000

# %% [markdown]
# ## Taking the Average

# %%
keys = word2vec.keys()

# %%
x_tr = []

for x in range(len(words)):
    filtered_init = []
    for i in range(len(words[x])):
        if (words[x][i] in keys):
            filtered_init.append(words[x][i])
            filtered = set(filtered_init)
        t = [word2vec[w].reshape(50) for w in filtered]
    x_tr.append(np.average(t, axis=0))

# x = np.array(x_tr)
x_tr
# Out:
# [array([ 0.17039013,  0.316874  ,  0.0769251 ,  0.024993  ,  0.2336751 ,
#          0.0097701 , -0.2780699 , -0.1513718 , -0.2345509 ,  0.2776064 ,
#         -0.0436095 ,  0.2246413 , -0.0406724 ,  0.009267  ,  0.4785861 ,
#          0.3444467 , -0.402169  , -0.1542593 , -0.090973  , -0.3679115 ,
#          0.1105163 ,  0.1681814 ,  0.4869354 ,  0.100755  ,  0.3127284 ,
#         -1.3446656 , -0.7357431 ,  0.3157422 ,  0.5164237 , -0.52233   ,
#          2.47548   ,  0.17911044, -0.2674899 , -0.306926  ,  0.02842028,
#         -0.1377787 ,  0.2188867 ,  0.0093702 , -0.0819997 , -0.0436157 ,
#          0.1075786 ,  0.297531  , -0.191514  ,  0.0618058 ,  0.0225586 ,
#          0.0974955 ,  0.03822657,  0.0187831 ,  0.09164388,  0.1959433 ]),
#  array([ 0.1615816 ,  0.187342  ,  0.390088  , -0.070598  ,  0.2066448 ,
#          0.0072564 , -0.164818  , -0.2787924 , -0.23759284, -0.0580208 ,
#          0.0564448 ,  0.355628  , -0.5281052 , -0.251774  ,  0.2497166 ,
#          0.12228   , -0.1998096 ,  0.080416  ,  0.0915792 , -0.563498  ,
#         -0.335008  ,  0.054406  ,  0.32186   ,  0.1707692 , -0.09512   ,
#         -1.288724  , -0.5564462 , -0.0934772 ,  0.296331  , -0.54599   ,
#          2.59714   ,  0.3310694 , -0.4754066 ,  0.1586628 ,  0.134404  ,
#         -0.2706016 ,  0.2518886 , -0.128014  ,  0.0654636 , -0.1970996 ,
#          0.229278  , -0.18741   ,  0.0480328 ,  0.40103   ,  0.2624774 ,
#         -0.1905664 ,  0.0707162 , -0.0421856 , -0.1076454 ,  0.2887162 ]),
#         -0.42962 ,  0.10441 ,  0.98788 , -0.73067 ,  0.097214, -0.10394 ,
#          0.45725 ,  0.45294 , -0.41688 ,  0.18072 ,  0.10714 , -0.21149 ,
#          0.44587 , -0.90336 , -1.1927  ,  0.55785 ,  1.214   ,  0.028225,
#          0.50494 ,  0.060945, -0.15574 , -0.5117  , -1.1762  ,  0.17561 ,
#          0.45742 , -0.74473 , -1.0748  , -0.34725 , -0.76378 , -0.7222  ,
#          0.3756  ,  0.63219 ,  0.11867 ,  0.20931 , -0.83423 ,  0.70452 ,
#          0.89057 ,  0.45139 ]),
#  array([ 6.69963077e-02,  3.78707154e-01, -3.35213846e-02, -2.14115000e-01,
#          4.39717692e-01,  1.11773538e-01, -3.89288462e-01, -1.30430769e-01,
#         -2.58168462e-01,  2.43544615e-02, -2.23188538e-01,  3.57433538e-01,
#         -2.78468462e-01, -7.32690000e-02,  4.88658462e-01,  2.02862846e-01,
#          3.63542615e-01, -8.02815385e-03, -1.57294338e-01, -3.92780769e-01,
#         -5.26376923e-03,  3.71276000e-01,  1.52041154e-01,  3.79580769e-02,
#          2.45429646e-01, -1.37447385e+00, -5.23813846e-01, -7.78158462e-02,
#          2.86764615e-01, -2.96702938e-01,  2.69196154e+00,  3.00347692e-01,
#         -1.20919115e-01, -3.59947092e-01,  3.38870769e-02,  3.48284615e-03,
#         -1.75284077e-02, -1.19071615e-01,  2.21992769e-01, -4.25654615e-01,
#         -2.16066462e-01,  3.01623615e-01,  5.20827538e-02,  2.80307692e-03,
#          1.11769231e-03,  1.94128385e-01, -1.64190723e-01, -3.53305769e-01,
#         -2.48959231e-02,  3.04675385e-01]),
#  array([ 0.123905 , -0.25938  , -0.077397 , -0.576745 ,  0.246995 ,
#          0.159755 , -0.3533945,  0.2338505, -0.60419  ,  0.373065 ,
#         -0.06821  ,  0.55624  , -0.660095 , -0.192785 ,  0.83275  ,
#          0.261155 ,  0.307405 ,  0.0228635, -0.337695 , -0.231845 ,
#         -0.462495 ,  0.236096 ,  0.56458  ,  0.14312  ,  0.8205   ,
#         -1.86435  , -1.10066  ,  0.354911 ,  0.91431  , -0.382305 ,
#          2.88635  ,  0.24004  ,  0.412837 , -0.4221695, -0.098662 ,
#         -0.059055 , -0.0311201,  0.13923  ,  0.46761  , -0.34812  ,
#         -0.53741  ,  0.028104 ,  0.0953735,  0.563015 ,  0.2843   ,
#          0.090796 , -0.126125 ,  0.1512975,  0.4791465,  0.489855 ]),
#  ...]

# %%
x_te = []

for x in range(len(words_te)):
    filtered_init = []
    for i in range(len(words_te[x])):
        if (words_te[x][i] in keys):
            filtered_init.append(words_te[x][i])
            filtered = set(filtered_init)
        t = [word2vec[w].reshape(50) for w in filtered]
    x_te.append(np.average(t, axis=0))

x_test = np.array(x_te)

# %% [markdown]
# # Prepare X,y #

# %%
X = np.array(x_tr)
y = y_train_df['is_positive_sentiment'].to_numpy()
feat_num = X.shape[1]

# %%
import sklearn.metrics

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score

# %% [markdown]
# # SVM

# %%
import numpy as np

from sklearn.datasets import make_blobs, make_circles
from sklearn.svm import SVC

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline
import seaborn as sns; sns.set()

# %% [markdown]
# ### CV without the best C

# %% [markdown]
# #### rbf

# %%
print("-----------------\nClassify with base data, 5 folds\n-----------------")

k = 3
kfold = KFold(n_splits=k)
train_scores = []
test_scores = []
model = SVC(kernel='rbf')

for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X[train_idx,:], X[test_idx,:]
    y_train, y_test = y[train_idx], y[test_idx]
    
    model.fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    print("Train score: ", score_train)
    print("Test score: ", score_test)
    
    train_scores.append(score_train)
    test_scores.append(score_test)
    
print("\nAverage train accuracy: ", np.average(score_train))
print("Average test accuracy: ", np.average(score_test))
# Out:
# -----------------
# Classify with base data, 5 folds
# -----------------
# Train score:  0.8025
# Test score:  0.75875
# Train score:  0.813125
# Test score:  0.755
# Train score:  0.79625
# Test score:  0.77
#
# Average train accuracy:  0.79625
# Average test accuracy:  0.77

# %% [markdown]
# #### linear

# %%
print("-----------------\nClassify with base data, 5 folds\n-----------------")

k = 3
kfold = KFold(n_splits=k)
train_scores = []
test_scores = []
model = SVC(kernel='linear')

for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X[train_idx,:], X[test_idx,:]
    y_train, y_test = y[train_idx], y[test_idx]
    
    model.fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    print("Train score: ", score_train)
    print("Test score: ", score_test)
    
    train_scores.append(score_train)
    test_scores.append(score_test)
    
print("\nAverage train accuracy: ", np.average(score_train))
print("Average test accuracy: ", np.average(score_test))
# Out:
# -----------------
# Classify with base data, 5 folds
# -----------------
# Train score:  0.785625
# Test score:  0.76125
# Train score:  0.7975
# Test score:  0.74125
# Train score:  0.77375
# Test score:  0.7525
#
# Average train accuracy:  0.77375
# Average test accuracy:  0.7525

# %% [markdown]
# #### sigmoid

# %%
print("-----------------\nClassify with base data, 5 folds\n-----------------")

k = 3
kfold = KFold(n_splits=k)
train_scores = []
test_scores = []
model = SVC(kernel='sigmoid')

for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X[train_idx,:], X[test_idx,:]
    y_train, y_test = y[train_idx], y[test_idx]
    
    model.fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    print("Train score: ", score_train)
    print("Test score: ", score_test)
    
    train_scores.append(score_train)
    test_scores.append(score_test)
    
print("\nAverage train accuracy: ", np.average(score_train))
print("Average test accuracy: ", np.average(score_test))
# Out:
# -----------------
# Classify with base data, 5 folds
# -----------------
# Train score:  0.74
# Test score:  0.70125
# Train score:  0.73125
# Test score:  0.72875
# Train score:  0.760625
# Test score:  0.7425
#
# Average train accuracy:  0.760625
# Average test accuracy:  0.7425

# %% [markdown]
# ### CV with the best C

# %% [markdown]
# #### c and gamma

# %%
# C_range = np.logspace(1/5, 0.9/4, 20)
C_range = np.logspace(-1, 9, 30)
gamma_range = np.logspace(-9, 3, 5)
model_list = []
aver_train_scoreC = []
aver_test_scoreC = []
aver_train_lossC = []
aver_test_lossC = []


for C in C_range:
    for g in gamma_range:
        k = 3
        kfold = KFold(n_splits=k)

        train_scores = []
        test_scores = []
        train_loss = []
        test_loss = []

        model = SVC(kernel='rbf', C=C, gamma=g,probability=True)
        for train_idx, test_idx in kfold.split(X):
            X_train, X_test = X[train_idx,:], X[test_idx,:]
            y_train, y_test = y[train_idx], y[test_idx]


            model.fit(X_train, y_train)
            pred_train = model.predict_proba(X_train)
            pred_test = model.predict_proba(X_test)

            # Score
            score_train = model.score(X_train, y_train)
            score_test = model.score(X_test, y_test)
    #         print("Train score: ", score_train)
    #         print("Test score: ", score_test)
            train_scores.append(score_train)
            test_scores.append(score_test)

            # Log loss
            log_loss_train = sklearn.metrics.log_loss(y_train,pred_train)
            log_loss_test = sklearn.metrics.log_loss(y_test,pred_test)
    #         print("Train loss: ", log_loss_train)
    #         print("Test loss: ", log_loss_test)
            train_loss.append(log_loss_train)
            test_loss.append(log_loss_test)


        print("\nFor C value : ", C)
        print("\nFor C value : ", g)
        
        print("\nAverage train accuracy: ", np.average(score_train))
        print("Average test accuracy: ", np.average(score_test))
        print("\nAverage train loss: ", np.average(train_loss))
        print("Average test loss: ", np.average(test_loss))

        print('------------------------------------------------\n')

        model_list.append(model)
        aver_train_scoreC.append(np.average(score_train))
        aver_test_scoreC.append(np.average(score_test))
        aver_train_lossC.append(np.average(train_loss))
        aver_test_lossC.append(np.average(test_loss))
# Out:
# For C value :  0.1
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6932208897045765
# Average test loss:  0.6932208895193895
# ------------------------------------------------
#
#
# For C value :  0.1
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  0.1
#
# For C value :  0.001
#
# Average train accuracy:  0.74125
# Average test accuracy:  0.745
#
# Average train loss:  0.6935377411544419
# Average test loss:  0.6937158636111048
# ------------------------------------------------
#
#
# For C value :  0.1
#
# For C value :  1.0
#
# Average train accuracy:  0.69375
# Average test accuracy:  0.62625
#
# Average train loss:  0.5317755968741081
# Average test loss:  0.6366253178746546
# ------------------------------------------------
#
#
# For C value :  0.1
#
# For C value :  1000.0
#
# Average train accuracy:  0.506875
# Average test accuracy:  0.5
#
# Average train loss:  0.7012499687562528
# Average test loss:  0.6932411778569708
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931963137666806
# Average test loss:  0.6931963137538594
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6932080290900079
# Average test loss:  0.6932079750528
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# For C value :  0.001
#
# Average train accuracy:  0.74125
# Average test accuracy:  0.745
#
# Average train loss:  0.6934534519368114
# Average test loss:  0.6933241174588051
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# For C value :  1.0
#
# Average train accuracy:  0.86375
# Average test accuracy:  0.66875
#
# Average train loss:  0.43400225375268925
# Average test loss:  0.6213364389433326
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# For C value :  1000.0
#
# Average train accuracy:  0.506875
# Average test accuracy:  0.5
#
# Average train loss:  0.7030679037337207
# Average test loss:  0.6933436875229363
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931732997300744
# Average test loss:  0.693173298937254
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931668184599648
# Average test loss:  0.6931667739643207
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# For C value :  0.001
#
# Average train accuracy:  0.74125
# Average test accuracy:  0.745
#
# Average train loss:  0.6746108446094726
# Average test loss:  0.678344105012369
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# For C value :  1.0
#
# Average train accuracy:  0.925625
# Average test accuracy:  0.70875
#
# Average train loss:  0.289678504249802
# Average test loss:  0.6010603812622618
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.7090656300701751
# Average test loss:  0.6932581732829654
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6932269120841603
# Average test loss:  0.6932269119510478
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931729057715202
# Average test loss:  0.6931727930731185
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# For C value :  0.001
#
# Average train accuracy:  0.6875
# Average test accuracy:  0.69875
#
# Average train loss:  0.5583470162122507
# Average test loss:  0.5725913053135878
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# For C value :  1.0
#
# Average train accuracy:  0.968125
# Average test accuracy:  0.7175
#
# Average train loss:  0.15091849531901533
# Average test loss:  0.5961581577654719
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.043866580447759464
# Average test loss:  0.6920242283714236
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931994936802907
# Average test loss:  0.693199121942528
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# For C value :  0.001
#
# Average train accuracy:  0.736875
# Average test accuracy:  0.74375
#
# Average train loss:  0.5174529762966478
# Average test loss:  0.5366887045083854
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# For C value :  1.0
#
# Average train accuracy:  0.99125
# Average test accuracy:  0.70375
#
# Average train loss:  0.10070170869973033
# Average test loss:  0.6080712020414712
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.04658424028067709
# Average test loss:  0.692127250253332
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6932325719089635
# Average test loss:  0.6932316754696286
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# For C value :  0.001
#
# Average train accuracy:  0.7575
# Average test accuracy:  0.765
#
# Average train loss:  0.49904197623634805
# Average test loss:  0.5212981266123345
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.705
#
# Average train loss:  0.08214663977903865
# Average test loss:  0.6198383004117534
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.05302298369536886
# Average test loss:  0.6923377379401735
# ------------------------------------------------
#
#
# For C value :  11.721022975334806
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  11.721022975334806
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.693209112099824
# Average test loss:  0.6932079283097986
# ------------------------------------------------
#
#
# For C value :  11.721022975334806
#
# For C value :  0.001
#
# Average train accuracy:  0.7675
# Average test accuracy:  0.77
#
# Average train loss:  0.48554302338614325
# Average test loss:  0.5138235229713272
# ------------------------------------------------
#
#
# For C value :  11.721022975334806
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08516997791686202
# Average test loss:  0.6205335095913426
# ------------------------------------------------
# For C value :  11.721022975334806
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.03744515938441224
# Average test loss:  0.6925984068837107
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931712358672454
# Average test loss:  0.6931712345290538
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# For C value :  0.001
#
# Average train accuracy:  0.77375
# Average test accuracy:  0.775
#
# Average train loss:  0.47570193436900543
# Average test loss:  0.5057213373036499
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08130013058694703
# Average test loss:  0.6212160235390056
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.07368196817374222
# Average test loss:  0.6921495803641124
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931910419561769
# Average test loss:  0.6931774059590063
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# For C value :  0.001
#
# Average train accuracy:  0.774375
# Average test accuracy:  0.77125
#
# Average train loss:  0.46840822920358843
# Average test loss:  0.504683328424469
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.0856262267042713
# Average test loss:  0.6206133516523833
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.08706408499150954
# Average test loss:  0.6931371902945971
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931879895658163
# Average test loss:  0.6931878046648551
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6931535262431266
# Average test loss:  0.6931514638973647
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# For C value :  0.001
#
# Average train accuracy:  0.77625
# Average test accuracy:  0.7575
#
# Average train loss:  0.46571448392856357
# Average test loss:  0.5077683308083022
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08729991142383602
# Average test loss:  0.6207278439622771
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.07090731240110773
# Average test loss:  0.692654761822738
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.6922681575838349
# Average test loss:  0.6926008273072561
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# For C value :  0.001
#
# Average train accuracy:  0.78
# Average test accuracy:  0.75625
#
# Average train loss:  0.4633684389664532
# Average test loss:  0.506072696258114
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.0870740085924614
# Average test loss:  0.6209935614405641
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.021059437030811926
# Average test loss:  0.6919428009199153
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931737766043113
# Average test loss:  0.6931737107549428
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# For C value :  1e-06
#
# Average train accuracy:  0.74625
# Average test accuracy:  0.76
#
# Average train loss:  0.662668038742527
# Average test loss:  0.6679945209915233
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# For C value :  0.001
#
# Average train accuracy:  0.77375
# Average test accuracy:  0.7625
#
# Average train loss:  0.4611937502464118
# Average test loss:  0.5026887605033242
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08125374349223462
# Average test loss:  0.621289788709261
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.06811216275374861
# Average test loss:  0.6923197906143823
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# For C value :  1e-06
#
# Average train accuracy:  0.7025
# Average test accuracy:  0.71625
#
# Average train loss:  0.5380198253070297
# Average test loss:  0.553135814604988
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# For C value :  0.001
#
# Average train accuracy:  0.776875
# Average test accuracy:  0.76
#
# Average train loss:  0.4546837412895875
# Average test loss:  0.5033220377109094
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08272735603437727
# Average test loss:  0.6216881786063887
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.04832945092477709
# Average test loss:  0.6924185976275886
# ------------------------------------------------
#
#
# For C value :  3039.195382313201
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6932464094887708
# Average test loss:  0.693246336859529
# ------------------------------------------------
#
#
# For C value :  3039.195382313201
#
# For C value :  1e-06
#
# Average train accuracy:  0.75
# Average test accuracy:  0.7575
#
# Average train loss:  0.5107624274372001
# Average test loss:  0.5292107521636611
# ------------------------------------------------
# For C value :  3039.195382313201
#
# For C value :  0.001
#
# Average train accuracy:  0.783125
# Average test accuracy:  0.76125
#
# Average train loss:  0.4456185747025699
# Average test loss:  0.501952769720145
# ------------------------------------------------
#
#
# For C value :  3039.195382313201
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.0836985702818525
# Average test loss:  0.6208332801218052
# ------------------------------------------------
#
#
# For C value :  3039.195382313201
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.04468599519829833
# Average test loss:  0.6923732666038805
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# For C value :  1e-06
#
# Average train accuracy:  0.761875
# Average test accuracy:  0.7675
#
# Average train loss:  0.4943679820398856
# Average test loss:  0.5178324021973366
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# For C value :  0.001
#
# Average train accuracy:  0.801875
# Average test accuracy:  0.76375
#
# Average train loss:  0.4305261802804159
# Average test loss:  0.500272750765643
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08291912565277021
# Average test loss:  0.621771607804512
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.05475620933325414
# Average test loss:  0.6922372844198358
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6932133449843798
# Average test loss:  0.6932120992593344
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# For C value :  1e-06
#
# Average train accuracy:  0.774375
# Average test accuracy:  0.77
#
# Average train loss:  0.4821545766682946
# Average test loss:  0.5106298231410075
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# For C value :  0.001
#
# Average train accuracy:  0.81875
# Average test accuracy:  0.77
#
# Average train loss:  0.410091424613249
# Average test loss:  0.5041462313735664
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08153251764048423
# Average test loss:  0.6212896105035822
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.05050826671605597
# Average test loss:  0.6926530603947083
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.693369546647001
# Average test loss:  0.6933004971018861
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# For C value :  1e-06
#
# Average train accuracy:  0.774375
# Average test accuracy:  0.77125
#
# Average train loss:  0.4740308074452329
# Average test loss:  0.5042423518155692
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# For C value :  0.001
#
# Average train accuracy:  0.8425
# Average test accuracy:  0.75875
#
# Average train loss:  0.38509140655372254
# Average test loss:  0.5135579815574876
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08391909132310461
# Average test loss:  0.6206921780981206
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.05014248099835661
# Average test loss:  0.6919463856305511
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6931471805599451
# Average test loss:  0.6931471805599451
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# For C value :  1e-06
#
# Average train accuracy:  0.77125
# Average test accuracy:  0.76625
#
# Average train loss:  0.4684218520264907
# Average test loss:  0.505343190516011
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# For C value :  0.001
#
# Average train accuracy:  0.856875
# Average test accuracy:  0.74
#
# Average train loss:  0.36618818520184176
# Average test loss:  0.5336494176223097
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08716468967061537
# Average test loss:  0.6209132685197307
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.04564306490989167
# Average test loss:  0.6922051708811786
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.693352153649391
# Average test loss:  0.6932337185666899
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# For C value :  1e-06
#
# Average train accuracy:  0.776875
# Average test accuracy:  0.755
#
# Average train loss:  0.46667350669723867
# Average test loss:  0.5092412802406777
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# For C value :  0.001
#
# Average train accuracy:  0.885
# Average test accuracy:  0.73625
#
# Average train loss:  0.3549902444108977
# Average test loss:  0.5630587358178915
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08305170752757488
# Average test loss:  0.620988878499195
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.044297845038918975
# Average test loss:  0.6926942547190073
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# For C value :  1e-09
#
# Average train accuracy:  0.5
# Average test accuracy:  0.5
#
# Average train loss:  0.6910711286213721
# Average test loss:  0.6916533782343972
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# For C value :  1e-06
#
# Average train accuracy:  0.775625
# Average test accuracy:  0.755
#
# Average train loss:  0.46634102843212694
# Average test loss:  0.5073693767334023
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# For C value :  0.001
#
# Average train accuracy:  0.91125
# Average test accuracy:  0.70875
#
# Average train loss:  0.35527582582195905
# Average test loss:  0.607204673928283
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08668062136009859
# Average test loss:  0.6203825089235636
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.0625312496814931
# Average test loss:  0.6926179760479451
# ------------------------------------------------
# For C value :  788046.281566992
#
# For C value :  1e-09
#
# Average train accuracy:  0.511875
# Average test accuracy:  0.505
#
# Average train loss:  0.6776700469092122
# Average test loss:  0.680707290324784
# ------------------------------------------------
#
#
# For C value :  788046.281566992
#
# For C value :  1e-06
#
# Average train accuracy:  0.774375
# Average test accuracy:  0.7525
#
# Average train loss:  0.46660457064796357
# Average test loss:  0.5104965563731338
# ------------------------------------------------
#
#
# For C value :  788046.281566992
#
# For C value :  0.001
#
# Average train accuracy:  0.93875
# Average test accuracy:  0.7025
#
# Average train loss:  0.3675988348454618
# Average test loss:  0.6333205061387363
# ------------------------------------------------
#
#
# For C value :  788046.281566992
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08914816984552058
# Average test loss:  0.6212329777587796
# ------------------------------------------------
#
#
# For C value :  788046.281566992
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.09072681854217252
# Average test loss:  0.6915311508295102
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# For C value :  1e-09
#
# Average train accuracy:  0.65625
# Average test accuracy:  0.66375
#
# Average train loss:  0.6282656546190041
# Average test loss:  0.6356201765637385
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# For C value :  1e-06
#
# Average train accuracy:  0.775
# Average test accuracy:  0.75625
#
# Average train loss:  0.4692823456090476
# Average test loss:  0.505045279901383
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# For C value :  0.001
#
# Average train accuracy:  0.955625
# Average test accuracy:  0.67875
#
# Average train loss:  0.3921578523433906
# Average test loss:  0.6477348401929538
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08169236941687535
# Average test loss:  0.6207486499181086
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.04199672652785722
# Average test loss:  0.692548466587018
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# For C value :  1e-09
#
# Average train accuracy:  0.739375
# Average test accuracy:  0.75
#
# Average train loss:  0.5723298702692482
# Average test loss:  0.5849724782021237
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# For C value :  1e-06
#
# Average train accuracy:  0.780625
# Average test accuracy:  0.7475
#
# Average train loss:  0.46985293232874353
# Average test loss:  0.5092666890826445
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# For C value :  0.001
#
# Average train accuracy:  0.935
# Average test accuracy:  0.6775
#
# Average train loss:  0.40259005766815564
# Average test loss:  0.6688569925425089
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.07985170153187844
# Average test loss:  0.6208713356370095
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.043673383155931826
# Average test loss:  0.6930435264261224
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# For C value :  1e-09
#
# Average train accuracy:  0.7025
# Average test accuracy:  0.715
#
# Average train loss:  0.5555822862481866
# Average test loss:  0.5571548130065404
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# For C value :  1e-06
#
# Average train accuracy:  0.775625
# Average test accuracy:  0.75125
#
# Average train loss:  0.4714605264651501
# Average test loss:  0.5076205123080215
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# For C value :  0.001
#
# Average train accuracy:  0.924375
# Average test accuracy:  0.69
#
# Average train loss:  0.4272148385593228
# Average test loss:  0.6760162766833188
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.07846314915929042
# Average test loss:  0.6216216822962805
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.06075894818002536
# Average test loss:  0.6917636357831357
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# For C value :  1e-09
#
# Average train accuracy:  0.53875
# Average test accuracy:  0.56
#
# Average train loss:  0.8111704581023527
# Average test loss:  0.8081830201799939
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# For C value :  1e-06
#
# Average train accuracy:  0.769375
# Average test accuracy:  0.7575
#
# Average train loss:  0.4749385773118058
# Average test loss:  0.5083607876332835
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# For C value :  0.001
#
# Average train accuracy:  0.895
# Average test accuracy:  0.6675
#
# Average train loss:  0.42011727750329
# Average test loss:  0.6905828987922077
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08780886096994593
# Average test loss:  0.6202580299376931
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.01856769768049876
# Average test loss:  0.6926092716276665
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# For C value :  1e-09
#
# Average train accuracy:  0.50375
# Average test accuracy:  0.5075
#
# Average train loss:  0.6681687679293363
# Average test loss:  0.6600024295956765
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# For C value :  1e-06
#
# Average train accuracy:  0.766875
# Average test accuracy:  0.7575
#
# Average train loss:  0.47422808507778136
# Average test loss:  0.5198384665128665
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# For C value :  0.001
#
# Average train accuracy:  0.880625
# Average test accuracy:  0.65
#
# Average train loss:  0.4168595545248643
# Average test loss:  0.7012338541072315
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.07845594998996012
# Average test loss:  0.6214444372283685
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.058263413719187494
# Average test loss:  0.692363743654682
# ------------------------------------------------
#
#
# For C value :  92367085.71873884
#
# For C value :  1e-09
#
# Average train accuracy:  0.50125
# Average test accuracy:  0.50625
#
# Average train loss:  0.6843836374709552
# Average test loss:  0.68036538066669
# ------------------------------------------------
#
#
# For C value :  92367085.71873884
#
# For C value :  1e-06
#
# Average train accuracy:  0.769375
# Average test accuracy:  0.74625
#
# Average train loss:  0.4741708801888758
# Average test loss:  0.5196481597614109
# ------------------------------------------------
#
#
# For C value :  92367085.71873884
#
# For C value :  0.001
#
# Average train accuracy:  0.875625
# Average test accuracy:  0.6525
#
# Average train loss:  0.38332516033045955
# Average test loss:  0.764862604154764
# ------------------------------------------------
# For C value :  92367085.71873884
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08511804158597176
# Average test loss:  0.6210239535909422
# ------------------------------------------------
#
#
# For C value :  92367085.71873884
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.022935094405104117
# Average test loss:  0.6924404366722873
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# For C value :  1e-09
#
# Average train accuracy:  0.50125
# Average test accuracy:  0.50625
#
# Average train loss:  1.6451984445303227
# Average test loss:  1.5384699530891517
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# For C value :  1e-06
#
# Average train accuracy:  0.769375
# Average test accuracy:  0.7675
#
# Average train loss:  0.47502341649504953
# Average test loss:  0.5122831705265404
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# For C value :  0.001
#
# Average train accuracy:  0.871875
# Average test accuracy:  0.645
#
# Average train loss:  0.36058118804144357
# Average test loss:  0.8509255891915073
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08752102761346776
# Average test loss:  0.6205340972944247
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.06196126425404851
# Average test loss:  0.6924133799541909
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# For C value :  1e-09
#
# Average train accuracy:  0.501875
# Average test accuracy:  0.505
#
# Average train loss:  0.672123175452255
# Average test loss:  0.6744954652709163
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# For C value :  1e-06
#
# Average train accuracy:  0.774375
# Average test accuracy:  0.76
#
# Average train loss:  0.47401022897882666
# Average test loss:  0.5058527107736647
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# For C value :  0.001
#
# Average train accuracy:  0.871875
# Average test accuracy:  0.655
#
# Average train loss:  0.3608571893267956
# Average test loss:  1.0726584046219603
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08792649594243078
# Average test loss:  0.61978631836192
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.055989649145516206
# Average test loss:  0.6918750804458753
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# For C value :  1e-09
#
# Average train accuracy:  0.501875
# Average test accuracy:  0.50375
#
# Average train loss:  0.6633325285666843
# Average test loss:  0.6607319209936741
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# For C value :  1e-06
#
# Average train accuracy:  0.771875
# Average test accuracy:  0.75625
#
# Average train loss:  0.475324790976648
# Average test loss:  0.5159016640771932
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# For C value :  0.001
#
# Average train accuracy:  0.874375
# Average test accuracy:  0.66
#
# Average train loss:  0.33232034278799827
# Average test loss:  1.477708983879661
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# For C value :  1.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.71125
#
# Average train loss:  0.08241004759913911
# Average test loss:  0.6216408014931555
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# For C value :  1000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.5025
#
# Average train loss:  0.02842747340474454
# Average test loss:  0.6918097106338905
# ------------------------------------------------

# %% [markdown]
# #### just C

# %%
# C_range = np.logspace(1/5, 0.9/4, 20)
C_range = np.logspace(-1, 9, 30)
# gamma_range = np.logspace(-9, 3, 5)
model_list = []
aver_train_scoreC = []
aver_test_scoreC = []
aver_train_lossC = []
aver_test_lossC = []


for C in C_range:
    k = 3
    kfold = KFold(n_splits=k)

    train_scores = []
    test_scores = []
    train_loss = []
    test_loss = []

    model = SVC(kernel='rbf', C=C, probability=True)
    for train_idx, test_idx in kfold.split(X):
        X_train, X_test = X[train_idx,:], X[test_idx,:]
        y_train, y_test = y[train_idx], y[test_idx]


        model.fit(X_train, y_train)
        pred_train = model.predict_proba(X_train)
        pred_test = model.predict_proba(X_test)

        # Score
        score_train = model.score(X_train, y_train)
        score_test = model.score(X_test, y_test)
#         print("Train score: ", score_train)
#         print("Test score: ", score_test)
        train_scores.append(score_train)
        test_scores.append(score_test)

        # Log loss
        log_loss_train = sklearn.metrics.log_loss(y_train,pred_train)
        log_loss_test = sklearn.metrics.log_loss(y_test,pred_test)
#         print("Train loss: ", log_loss_train)
#         print("Test loss: ", log_loss_test)
        train_loss.append(log_loss_train)
        test_loss.append(log_loss_test)


    print("\nFor C value : ", C)

    print("\nAverage train accuracy: ", np.average(score_train))
    print("Average test accuracy: ", np.average(score_test))
    print("\nAverage train loss: ", np.average(train_loss))
    print("Average test loss: ", np.average(test_loss))

    print('------------------------------------------------\n')

    model_list.append(model)
    aver_train_scoreC.append(np.average(score_train))
    aver_test_scoreC.append(np.average(score_test))
    aver_train_lossC.append(np.average(train_loss))
    aver_test_lossC.append(np.average(test_loss))
# Out:
# For C value :  0.1
#
# Average train accuracy:  0.7675
# Average test accuracy:  0.77125
#
# Average train loss:  0.4943191106972588
# Average test loss:  0.5222179555067926
# ------------------------------------------------
#
#
# For C value :  0.2212216291070449
#
# Average train accuracy:  0.77875
# Average test accuracy:  0.7725
#
# Average train loss:  0.47342758149032904
# Average test loss:  0.5122432238092112
# ------------------------------------------------
#
#
# For C value :  0.4893900918477494
#
# Average train accuracy:  0.79
# Average test accuracy:  0.7725
#
# Average train loss:  0.4524299842242033
# Average test loss:  0.5002994446900711
# ------------------------------------------------
#
#
# For C value :  1.0826367338740546
#
# Average train accuracy:  0.7975
# Average test accuracy:  0.7675
#
# Average train loss:  0.43307236080785355
# Average test loss:  0.49568756826938287
# ------------------------------------------------
#
#
# For C value :  2.395026619987486
#
# Average train accuracy:  0.810625
# Average test accuracy:  0.77125
#
# Average train loss:  0.41274586080209835
# Average test loss:  0.4935681158167782
# ------------------------------------------------
#
#
# For C value :  5.29831690628371
#
# Average train accuracy:  0.82875
# Average test accuracy:  0.76625
#
# Average train loss:  0.3874905297913571
# Average test loss:  0.49933058745553544
# ------------------------------------------------
#
#
# For C value :  11.721022975334806
#
# Average train accuracy:  0.85125
# Average test accuracy:  0.7575
#
# Average train loss:  0.3569477564825522
# Average test loss:  0.512727472236271
# ------------------------------------------------
#
#
# For C value :  25.92943797404667
#
# Average train accuracy:  0.879375
# Average test accuracy:  0.74625
#
# Average train loss:  0.32801583929460415
# Average test loss:  0.5332481329465766
# ------------------------------------------------
#
#
# For C value :  57.361525104486816
#
# Average train accuracy:  0.916875
# Average test accuracy:  0.73875
#
# Average train loss:  0.3066847200048764
# Average test loss:  0.5631834414766966
# ------------------------------------------------
#
#
# For C value :  126.89610031679234
#
# Average train accuracy:  0.951875
# Average test accuracy:  0.71125
#
# Average train loss:  0.3130167365262218
# Average test loss:  0.599948967377948
# ------------------------------------------------
#
#
# For C value :  280.72162039411785
#
# Average train accuracy:  0.974375
# Average test accuracy:  0.69375
#
# Average train loss:  0.32208212307469025
# Average test loss:  0.6304584309541822
# ------------------------------------------------
#
#
# For C value :  621.0169418915616
#
# Average train accuracy:  0.991875
# Average test accuracy:  0.67625
#
# Average train loss:  0.3387481568785183
# Average test loss:  0.6356094806111807
# ------------------------------------------------
#
#
# For C value :  1373.8237958832638
#
# Average train accuracy:  0.999375
# Average test accuracy:  0.67
#
# Average train loss:  0.3568629772413137
# Average test loss:  0.6415173586456829
# ------------------------------------------------
#
#
# For C value :  3039.195382313201
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36115899246269595
# Average test loss:  0.6434306811879099
# ------------------------------------------------
#
#
# For C value :  6723.357536499335
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36273532392612323
# Average test loss:  0.6415960540670519
# ------------------------------------------------
#
#
# For C value :  14873.521072935118
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36698415163927606
# Average test loss:  0.640527897010569
# ------------------------------------------------
#
#
# For C value :  32903.44562312671
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3583809723796075
# Average test loss:  0.6436672289971486
# ------------------------------------------------
#
#
# For C value :  72789.53843983161
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3542266947234141
# Average test loss:  0.6482408576214241
# ------------------------------------------------
#
#
# For C value :  161026.20275609425
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3663113951102141
# Average test loss:  0.6428169953969632
# ------------------------------------------------
#
#
# For C value :  356224.7890262444
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.35616744574605774
# Average test loss:  0.6446201841589451
# ------------------------------------------------
#
#
# For C value :  788046.281566992
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36176796438265124
# Average test loss:  0.6426827905915768
# ------------------------------------------------
#
#
# For C value :  1743328.8221999907
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3563876961896142
# Average test loss:  0.6459556207529906
# ------------------------------------------------
#
#
# For C value :  3856620.4211634723
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36505506037539986
# Average test loss:  0.6416658281149362
# ------------------------------------------------
#
#
# For C value :  8531678.524172815
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3498117993472052
# Average test loss:  0.6484700670814534
# ------------------------------------------------
#
#
# For C value :  18873918.221350998
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36693290441657617
# Average test loss:  0.6417560669945969
# ------------------------------------------------
#
#
# For C value :  41753189.36560409
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3590005984417466
# Average test loss:  0.6462510874139615
# ------------------------------------------------
#
#
# For C value :  92367085.71873884
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3679099048459819
# Average test loss:  0.6394013546926324
# ------------------------------------------------
#
#
# For C value :  204335971.7856948
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36110555413902806
# Average test loss:  0.6423959997020955
# ------------------------------------------------
#
#
# For C value :  452035365.63602406
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.36675796631144014
# Average test loss:  0.6396171593483148
# ------------------------------------------------
#
#
# For C value :  1000000000.0
#
# Average train accuracy:  1.0
# Average test accuracy:  0.67625
#
# Average train loss:  0.3634543351240059
# Average test loss:  0.6425899677356507
# ------------------------------------------------

# %%
min_loss = min(aver_test_lossC)
index_N2 = aver_test_lossC.index(min_loss)
# best_C =  C_range[index_N2]
# best_model = model_list[index_N2]
min_loss
# index_N2
# best_C
# Out:
# 0.4935681158167782

# %% [markdown]
# ## Accuracy

# %%
plt.xlabel('C values');
plt.ylabel('Accuracy score');
# plt.ylim([0.0, 1]);

# TODO
# p 
sns.lineplot(x = np.log(C_range), y = aver_train_scoreC, label = "Train", color = "red", marker='o')
sns.lineplot(x = np.log(C_range), y = aver_test_scoreC, label = "Test", color = "blue", marker='o')

# show a legend on the plot 
plt.legend() 
plt.title('Average accuracy score on Test/Validation set')
plt.show()

# print("Best C-value for LR: %.3f" % best_C) 
# print("Test set log-loss at best C-value: %.4f" % min_loss)

# %% [markdown]
# ## Log loss

# %%
plt.xlabel('C values');
plt.ylabel('logistic loss');
# plt.ylim([0.0, 1]);

# TODO
# p 
sns.lineplot(x = np.log(C_range), y = aver_train_lossC, label = "Train", color = "red", marker='o')
sns.lineplot(x = np.log(C_range), y = aver_test_lossC, label = "Test", color = "blue", marker='o')

# show a legend on the plot 
plt.legend() 
plt.title('Logistic loss on C-grid')
plt.show()

print("Best C-value for LR: %.3f" % best_C) 
print("Test set log-loss at best C-value: %.4f" % min_loss)
# Out:
# Best C-value for LR: 2.395
# Test set log-loss at best C-value: 0.4936

# %% [markdown]
# #### with d

# %%
C_range = np.logspace(-1, 10, 5)
gamma_range = np.logspace(-9, 3, 5)
d_range = [2,3,5,8,10]
model_list2 = []
aver_train_score2 = []
aver_test_score2 = []
aver_train_loss2 = []
aver_test_loss2 = []


for C in C_range:
    for g in gamma_range:
        for d in d_range:
            k = 3
            kfold = KFold(n_splits=k)

            train_scores = []
            test_scores = []
            train_loss = []
            test_loss = []

            model = SVC(kernel='rbf', C=C, gamma=g,degree=d)
            for train_idx, test_idx in kfold.split(X):
                X_train, X_test = X[train_idx,:], X[test_idx,:]
                y_train, y_test = y[train_idx], y[test_idx]

                model.fit(X_train, y_train)
                pred_train = model.predict(X_train)
                pred_test = model.predict(X_test)

                # Score
                score_train = model.score(X_train, y_train)
                score_test = model.score(X_test, y_test)
        #         print("Train score: ", score_train)
        #         print("Test score: ", score_test)
                train_scores.append(score_train)
                test_scores.append(score_test)

                # Log loss
                log_loss_train = sklearn.metrics.log_loss(y_train,pred_train)
                log_loss_test = sklearn.metrics.log_loss(y_test,pred_test)
        #         print("Train loss: ", log_loss_train)
        #         print("Test loss: ", log_loss_test)
                train_loss.append(log_loss_train)
                test_loss.append(log_loss_test)


#             print("\nFor C value : ", C)
#             print("\nFor gamma value : ", g)
#             print("\nFor degree : ", d)
            
#             print("\nAverage train accuracy: ", np.average(score_train))
#             print("Average test accuracy: ", np.average(score_test))
#             print("\nAverage train loss: ", np.average(train_loss))
#             print("Average test loss: ", np.average(test_loss))

            print('----\n')

            model_list2.append(model)
            aver_train_score2.append(np.average(score_train))
            aver_test_score2.append(np.average(score_test))
            aver_train_loss2.append(np.average(train_loss))
            aver_test_loss2.append(np.average(test_loss))

# %% [markdown]
# #### Best Log loss

# %%
min_loss = min(aver_test_loss)
index_N2 = aver_test_loss.index(min_loss)
# best_C =  C_grid[index_N2]
best_model = model_list[index_N2]

# %% [markdown]
# #### stability across Kfolds

# %%
print("-----------------\nClassify with base data, 5 folds\n-----------------")

K = [2,3,4,5,8,10]
K_train_loss = []
K_test_loss = []
for k in K:
    kfold = KFold(n_splits=k)
    train_scores = []
    test_scores = []
    train_loss = []
    test_loss = []
    
    for train_idx, test_idx in kfold.split(X):
        shuffler = np.random.permutation(len(X))
        X_shuffled = X[shuffler]
        y_shuffled = y[shuffler]
        X_train, X_test = X_shuffled[train_idx,:], X_shuffled[test_idx,:]
        y_train, y_test = y_shuffled[train_idx], y_shuffled[test_idx]

        model.fit(X_train, y_train)
        pred_train = best_model.predict_proba(X_train)
        pred_test = best_model.predict_proba(X_test)

        score_train = best_model.score(X_train, y_train)
        score_test = best_model.score(X_test, y_test)
        train_scores.append(score_train)
        test_scores.append(score_test)
        
        log_loss_train = sklearn.metrics.log_loss(y_train,pred_train)
        log_loss_test = sklearn.metrics.log_loss(y_test,pred_test)
        
        train_loss.append(log_loss_train)
        test_loss.append(log_loss_test)

    print("\nAverage train accuracy: ", np.average(score_train))
    print("Average test accuracy: ", np.average(score_test))
    print("Average train loss: ", np.average(train_loss))
    print("Average test loss: ", np.average(test_loss))
    
    K_train_loss.append(np.average(train_loss))
    K_test_loss.append(np.average(test_loss))
# Out:
# -----------------
# Classify with base data, 5 folds
# -----------------
#
# Average train accuracy:  0.9291666666666667
# Average test accuracy:  0.9266666666666666
# Average train loss:  0.1735694664310775
# Average test loss:  0.16055638497616537
#
# Average train accuracy:  0.928125
# Average test accuracy:  0.9275
# Average train loss:  0.17242154725131023
# Average test loss:  0.15634568260824375
#
# Average train accuracy:  0.9266666666666666
# Average test accuracy:  0.9316666666666666
# Average train loss:  0.16854908920701198
# Average test loss:  0.1626044351934498
#
# Average train accuracy:  0.928125
# Average test accuracy:  0.9270833333333334
# Average train loss:  0.16686237469702206
# Average test loss:  0.16786512973001894
#
# Average train accuracy:  0.929047619047619
# Average test accuracy:  0.92
# Average train loss:  0.16648540537295214
# Average test loss:  0.17110556801830645
#
# Average train accuracy:  0.925
# Average test accuracy:  0.9541666666666667
# Average train loss:  0.1659686941513512
# Average test loss:  0.17691100967405354

# %%
plt.xlabel('K from 2 to 12');
plt.ylabel('logistic loss');

sns.lineplot(x = K, y = K_train_loss, label = "Train Loss", color = "red", marker='o')
sns.lineplot(x = K, y = K_test_loss, label = "Test Loss", color = "blue", marker='o')

# show a legend on the plot 
plt.legend() 
plt.title('Log loss across K values')
plt.show()


print('standard deviation for training set: %.3f  ' %np.std(K_train_loss))
print('standard deviation for testing set: %.3f  ' %np.std(K_test_loss))

# %%
plt.xlabel('d, g pairs');
plt.ylabel('logistic loss');
plt.ylim([0.0, 1]);

# TODO
# p 
sns.lineplot(x = p, y = aver_train_loss, label = "Train Loss", color = "red", marker='o')
sns.lineplot(x = p, y = aver_test_loss,label = "Test Loss", color = "blue", marker='o')

# show a legend on the plot 
plt.legend() 
plt.title('Logistic loss on C-grid')
plt.show()

print("Best C-value for LR: %.3f" % best_C) 
print("Test set log-loss at best C-value: %.4f" % min_loss)

# %% [markdown]
# #### Result

# %%
yproba1_test = best_model.predict_proba(x_te)[:,1]
np.savetxt('yproba1_test.txt', yproba1_test)

# %%
x_te.shape
yproba1_test.shape
# Out:
# (600,)

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
parameters = {}

model = SVC(kernel='rbf', C=2.395, probability=True)

clf = GridSearchCV(model, parameters,cv=3)
clf.fit(X,y)
clf.cv_results_
# Out:
# {'mean_fit_time': array([1.00207551]),
#  'std_fit_time': array([0.32684134]),
#  'mean_score_time': array([0.14898896]),
#  'std_score_time': array([0.01446751]),
#  'params': [{}],
#  'split0_test_score': array([0.7675]),
#  'split1_test_score': array([0.75875]),
#  'split2_test_score': array([0.77125]),
#  'mean_test_score': array([0.76583333]),
#  'std_test_score': array([0.00523742]),
#  'rank_test_score': array([1], dtype=int32)}
